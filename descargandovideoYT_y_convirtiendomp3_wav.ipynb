# %%
## Instalando todas estas librerias antes de empezar a correr el programa
## Todas son necesarias para poder correr de manera correcta el programa
# !pip install pytube
# !pip install moviepy
# !pip install pydub
# !pip install ffmpeg
# !pip install moviepy
# !pip install SpeechRecognition
# !pip install -q moviepy
# !apt install imagemagick
# !pip install imageio==2.4.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 KB 1.9 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6084 sha256=befd8ad8e3da2a9ba1efa63153ed11ff32ead5eed7dd3aa3198b67d4144944e8
#   Stored in directory: /root/.cache/pip/wheels/30/33/46/5ab7eca55b9490dddbf3441c68a29535996270ef1ce8b9b6d7
# Successfully built ffmpeg
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
## Importando las librerias a utilizar
from pytube import YouTube
import moviepy.editor as mve
import speech_recognition as sr
from os import path
from pydub import AudioSegment
from moviepy.editor import *
import ffmpeg
from moviepy.video.io.VideoFileClip import VideoFileClip
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %% [markdown]
# DESARROLLANDO EL CODIGO

# %%
 
## Verificando las resoluciones disponibles del video
def resolucion_video(url):
    
    resolucion = []
    for stream in YouTube(url).streams:
        resolucion.append(stream.resolution)
    
    # Por si se repiten las resoluciones
    resolucion = list(set(resolucion))
    
    print('\n Las resoluciones disponibles son: \n')
    
    # Mostramos en orden y detallado, todas las resoluciones disponibles
    cont=0
    for i in resolucion:
        cont = cont + 1
        print('La resolución número ' + str(cont) + ' es: ', str(i))
        


## Descargando video y Convirtiendo el video mp4 en audio mp3
def descargando_convirtiendo(url):
    
    print('\n')
    resol = input('\n En que resolución necesitas el video: ')
    print('\n')
    
    # Descargamos el video solicitado, en la resolución indicada
    video = YouTube(url).streams.filter(res = resol, type='video',file_extension='mp4',progressive=True).first().download()
       
    #Por si se necesita eliminar esa parte de la ruta
    if "/content/" in video:
      video = video.replace("/content/","")
    
    #Convirtiendo de mp4 a mp3
    
    video_mp4 = video.replace("3gpp","mp4") ##Por si te descarga en extensión .3gpp
  
    audio_mp3 = input("Ingresa el nombre del archivo sin extensión: ") # Ingresamos un nombre para guardarlo de esta manera el audio
    audio_mp3 =str(audio_mp3) # Muchas veces se genera conflicto, por eso mejor, pasarlo a string lo ingresado
    
    videoclip = mve.VideoFileClip(video_mp4) #Hacemos que el video se guarde en formato video en la variable
    audioclip = videoclip.audio #Pasamos el video a formato audio
    audioclip.write_audiofile(f"{audio_mp3}.mp3") #Escribimos el audio en formato mp3

       
    #Convirtiendo de mp3 a wav

    entrada = audio_mp3+".mp3" #Le damos el mismo nombre del audio que escogimos
    salida = audio_mp3+".wav" #De igual manera el mismo nombre pero con extensión .wav

    sound = AudioSegment.from_mp3(entrada) #Incializamos y reconocemos el audio en formato mp3
    new_sound = sound.export(salida,format='wav') # Exportamos y convertimos el audio en formato wav
               

#Definimos un entry point, que nos llame a las funciones en cierto orden
if __name__ == '__main__':
    url = input('ingrese la URL del video a descargar: \n') #Indicamos el url del video a transcribir
    resolucion_video(url) #Conseguimos la lista de resoluciones disponibles
    descargando_convirtiendo(url) #Descargamos el video, convertimos a audio mp3, y luego convertimos a wav
# Out:
# ingrese la URL del video a descargar:
# https://www.youtube.com/watch?v=tAvEhNC9i3I
#
#  Las resoluciones disponibles son:
#
# La resolución número 1 es:  240p
# La resolución número 2 es:  1080p
# La resolución número 3 es:  144p
# La resolución número 4 es:  None
# La resolución número 5 es:  480p
# La resolución número 6 es:  720p
# La resolución número 7 es:  360p
#
#
#
#  En que resolución necesitas el video: 720p
#
#
# Ingresa el nombre del archivo sin extensión: test
# [MoviePy] Writing audio in test.mp3
# 100%|██████████| 10224/10224 [00:14<00:00, 713.24it/s]
# [MoviePy] Done.

# %% [markdown]
# METODOS ALTERNATIVOS PARA CONVERTIR DE MP4 A MP3

# %%
#METODO 1

video_2 = VideoFileClip(os.path.join("video.mp4"))
video_2.audio.write_audiofile(os.path.join("audio.mp3"))

## METODO 2

command2mp3 = f"ffmpeg -i video.mp4 audio.mp3"

command2wav = f"ffmpeg -i audio.mp3 audio.wav"

      #Execution of Video conversion commands using os Library:
os.system(command2mp3)
os.system(command2wav)
